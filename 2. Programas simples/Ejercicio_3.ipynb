# %% [markdown]
# Descripcion del enunciado: Una locomotora necesita 10s para alcanzar su velocidad normal que es 25m/s. Suponiendo que su movimiento es uniformemente acelerado ¿Que aceleracion se le ha comunicado y que espacio ha recorrido antes de alcanmzar la velocidad regular?
# Autor: Sofia Sanchez
# Fecha 2_09_2022
# Version 1.0

# %%
# Declaracion de Variables
var_ent_int_Vi = 0.0
var_ent_int_Tiempo = 0.0
var_ent_int_velocidadNor = 0.0
var_proSal_int_aceleracion = 0.0 # Variable que almacena
var_proSal_int_Espacio = 0.0 # Variable que almacena

# %%
# Captura de datos
var_ent_int_Vi = int(input("Velocidad inicial ;"))
var_ent_int_Tiempo = int(input("Tiempo ;"))
var_ent_int_velocidadNor = int(input("Velocidad normal ;"))
# Out:
# Velocidad inicial ;0
# Tiempo ;10
# Velocidad normal ;25

# %% [markdown]
# Velocidad inicial: 0
#
# Tiempo: 10
#
# Velocidad normal: 25

# %%
# Proceso
var_proSal_int_aceleracion = var_ent_int_velocidadNor/var_ent_int_Tiempo

# %%
# Proceso
var_proSal_float_Espacio = (1/2)*var_proSal_int_aceleracion*(var_ent_int_Tiempo**2)

# %%
# Salida
print(var_proSal_int_aceleracion)
# Out:
# 2.5

# %%
# Salida
print(var_proSal_int_Espacio)
# Out:
# 0.0
