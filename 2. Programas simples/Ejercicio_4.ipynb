# %% [markdown]
# Descripcion del enunciado: Un cuerpo posee una velocidad inicial de 12m/s y una acelercion de 2m/s2 ¿Cuanto tiempo tardara en adquirir una velocidad de 144km/h?
# Autor: Sofia Sanchez
# Fecha 03_09_2022
# Version 1.0

# %%
# Declaracion de variables
var_ent_int_Vi = 0.0
var_ent_int_Aceleracion = 0.0
var_ent_int_Vf = 0.0
var_proSal_int_Tiempo = 0.0 #Variable que almacena

# %%
# Captura de datos
var_ent_int_Vi = int(input("Velocidad inicial ;"))
var_ent_int_Aceleracion = int(input("Aceleracion ;"))
var_ent_int_Vf = int(input("Velocidad final ;"))
# Out:
# Velocidad inicial ;12
# Aceleracion ;2
# Velocidad final ;40

# %% [markdown]
# Velocidad Inicial: 12
#
# Aceleracion: 2
#
# Velocidad Final: 40

# %%
# Proceso
var_proSal_int_Tiempo = (var_ent_int_Vf - var_ent_int_Vi)/var_ent_int_Aceleracion

# %%
# Salida
print(var_proSal_int_Tiempo)
# Out:
# 14.0
