# %% [markdown]
# Descripcion del enunciado: Calcular el área de un cono de altura
# 1dm y altura inclinada 2dm
# Autor: Sofia Sanchez
# Fecha 04_09_2022
# Version 1.0

# %%
# Declaracion de variables
var_ent_float_Altura = 0.0
var_ent_float_Ai = 0.0
var_ent_float_Radio = 0.0
var_proSal_float_Area = 0.0 # Variable que almacena

# %%
# Captura de datos
var_ent_float_Altura = float(input("Altura ;"))
var_ent_float_Ai = float(input("Altura inclinada ;"))
var_ent_float_Radio = float(input("Radio ;"))
# Out:
# Altura ;1
# Altura inclinada ;2
# Radio ;1.7320

# %% [markdown]
# Altura: 1
#
# Altura inclinada: 2
#
# Radio: 3

# %%
# Proceso
var_proSal_float_Area = (var_ent_float_Radio + var_ent_float_Ai)*var_ent_float_Radio*3.1416

# %%
# Salida
print(var_proSal_float_Area)
# Out:
# 20.27243064
