# %% [markdown]
# Descripcion del enunciado: Hallar el área de un dodecaedro regular de arista de 2 cm
# Autor: Sofia Sanchez
# Fecha 06_09_2022
# Version 1.0

# %%
# Declaracion de variables
var_ent_float_Arista = 0.0
var_proSal_float_Area = 0.0 # Variable que almacena

# %%
# Captura de datos
var_ent_float_Arista = float(input("Arista ;"))
# Out:
# Arista ;2

# %% [markdown]
# Arista: 2

# %%
# Proceso
var_proSal_float_Area =

# %%
# Salida 
print(var_proSal_float_Area)
# Out:
# (72, 77757124)
