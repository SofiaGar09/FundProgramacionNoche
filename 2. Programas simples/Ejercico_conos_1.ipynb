# %% [markdown]
# Descripcion del enunciado: Calcular el área de un cono de altura inclinada
# 15cm y diámetro 6cm.
# Autor: Sofia Sanchez
# Fecha 04_09_2022
# Version 1.0

# %%
# Declaracion de variables
var_ent_Int_Ai = 0.0
var_ent_Int_Diametro = 0.0
var_ent_Int_RadioCono = 0.0
var_proSal_Int_Area = 0.0 #Variable que almacena

# %%
# Captura de datos
var_ent_Int_Ai = int(input("Altura inclinada ;"))
var_ent_Int_Diametro = int(input("Diametro ;"))
var_ent_Int_RadioCono = int(input("Radio del cono ;"))
# Out:
# Altura inclinada ;15
# Diametro ;6
# Radio del cono ;3

# %% [markdown]
# Altura inclinada: 15
#
# Diametro: 6
#
# Radio del cono: 3

# %%
# Proceso
var_proSal_Int_Area = (var_ent_Int_RadioCono + var_ent_Int_Ai)*3*3.1416

# %%
# Salida
print(var_proSal_Int_Area)
# Out:
# 169.6464
