# %% [markdown]
# Descripcion del Enunciado: Para un estudiante leer su nombre, las 3 notas de los parciales y calcular su nota definitiva e informa si aprobó o reprobo. La nota definitiva se calcula por promedio
# Autor: Grupo FP Noche
# Fecha: 31_08_2022
# Version: 1.0

# %%
# Declaracion de variables
var_ent_cad_nombreEstudiante = ""
var_ent_float_nota_PP = 0.0
var_ent_float_nota_SP = 0.0
var_ent_float_nota_TP = 0.0
var_proSal_float_notaDef = 0.0 # Variable que almacena

# %%
# Captura de Datos
var_ent_cad_nombreEstudiante = input("Nombre Estudiante ; ")
var_ent_float_nota_PP = float(input("Primer Parcial ;"))
var_ent_float_nota_SP = float(input("Segundo Parcial ;"))
var_ent_float_nota_TP = float(input("Tercer Parcial ;"))
# Out:
# Nombre Estudiante ; Sofia
# Primer Parcial ;4.0
# Segundo Parcial ;4.5
# Tercer Parcial ;4.0

# %% [markdown]
# Nombre Estudiante : Sofia Sanchez Garcia
#
# Primer Parcial : 4.0
#
# Segundo Parcial : 4.5
#
# Terce Parcial : 4.0

# %%
# Procesos
var_ent_float_nota_TP = (var_ent_float_nota_PP+var_ent_float_nota_SP+var_ent_float_nota_TP)/3

# %%
# Proceso saber si el estudiante aprobo o reprobo
if(var_proSal_float_notaDef>4.0):
  var_proSal_cad_concepto = "Aprobó - Te promueves"
else:
  var_proSal_cad_concepto = "Aprovo - Felicidades"

# %%
# Salidas
print("La nota definitiva de",var_ent_cad_nombreEstudiante +" es : ",str(var_ent_float_nota_TP) + "concepto : ",var_proSal_cad_concepto)
# Out:
# La nota definitiva de Sofia es :  4.166666666666667concepto :  Aprovo - Felicidades
