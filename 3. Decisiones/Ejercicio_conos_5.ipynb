# %% [markdown]
# Descripcion del enunciado: José tiene dos conos de igual altura: uno rojo de 3 cm de radio y otro azul de 6cm de radio. ¿El cono azul tiene el doble de volumen que el rojo?
# Autor: Sofia Sanchez
# Fecha 04_09_2022
# Version 1.0

# %%
# Declarar variables 
var_ent_float_Altura = 0.0
var_ent_float_RadioCR = 0.0
var_ent_float_RadioCA = 0.0
var_proSal_float_VolumenCR = 0.0 # Variable que almacena
var_proSal_float_volumenCA = 0.0 # Variable que almacena

# %%
# Captura de datos
var_ent_float_Altura = float(input("Altura ;"))
var_ent_float_RadioCR = float(input("Radio cono rojo ;"))
var_ent_float_RadioCA = float(input("Radio cono azul ;"))
# Out:
# Altura ;0.31
# Radio cono rojo ;3
# Radio cono azul ;6

# %% [markdown]
# Altura: 0.31
#
# Radio cono rojo: 3
#
# Radio cono azul: 6

# %%
# Proceso
var_proSal_float_VolumenCR = (3.1416*var_ent_float_RadioCR**2*var_ent_float_Altura)/3

# %%
# Proceso
var_proSal_float_volumenCA = (3.1416*var_ent_float_RadioCA**2*var_ent_float_Altura)/3

# %%
# Salida
print(var_proSal_float_VolumenCR)
# Out:
# 2.921688

# %%
#Salida
print(var_proSal_float_volumenCA)
# Out:
# 11.686752

# %%
# Saber si el cono azul tiene mas volumen que el rojo
if 11.28 > 2.92 :
  print ("El cono azul tiene el cuadruple de volumen que el cono rojo")
else:
  print("El cono rojo tiene el doble de volumen que el cono azul")
# Out:
# El cono azul tiene el cuadruple de volumen que el cono rojo
