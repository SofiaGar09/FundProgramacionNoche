# %% [markdown]
# Descripcion del enunciado: Ana tiene dos conos de igual radio: uno rojo de 5cm de altura y uno azul de 10cm de altura. ¿El cono azul tiene el doble de volumen que el rojo?
# Autor: Sofia Sanchez
# Fecha 06_09_2022
# Version 1.0

# %%
# Declarar variables 
var_ent_float_Radio = 0.0
var_ent_float_AlturaCR = 0.0
var_ent_float_AlturaCA = 0.0
var_proSal_float_VolumenCR = 0.0 # Variable que almacena
var_proSal_float_volumenCA = 0.0 # Variable que almacena

# %%
# Captutra de datos
var_ent_float_Radio = float(input("Radio ;"))
var_ent_float_AlturaCR = float(input("Altura cono rojo ;"))
var_ent_float_AlturaCA = float(input("Altura cono azul ;"))
# Out:
# Radio ;0.97
# Altura cono rojo ;5
# Altura cono azul ;10

# %% [markdown]
# Radio: 0.97
#
# Altura cono rojo: 5
#
# Altura cono azul: 10

# %%
# Proceso
var_proSal_float_VolumenCR = (3.1416*var_ent_float_AlturaCR*var_ent_float_Radio**2)/3

# %%
# Proceso
var_proSal_float_volumenCA = (3.1416*var_ent_float_AlturaCA*var_ent_float_Radio**2)/3

# %%
# Salida
print(var_proSal_float_VolumenCR)
# Out:
# 4.926552399999999

# %%
# Salida
print(var_proSal_float_volumenCA)
# Out:
# 9.853104799999999

# %%
# Saber si el cono azul tiene mas volumen que el rojo
if 9.85 > 4.92 :
   print ("El cono azul tiene el doble de volumen que el cono rojo")
else:
  print("El cono rojo tiene el doble de volumen que el cono azul")
# Out:
# El cono azul tiene el doble de volumen que el cono rojo
