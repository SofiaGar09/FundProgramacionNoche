# %%
# Declaracion de variable Valor 1
def rec_fib(n):
    if n > 1:
        return rec_fib(n-1) + rec_fib(n-2)
    return n
for i in range(9):
    print(rec_fib(i))
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %%
# Declaracion variable Valor 1
a = b = 1
while a <= 21:
    print(a)
    (a,b) = (b,a+b)
# Out:
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %% [markdown]
# Fuentes bibliograficas
# https://www.delftstack.com/es/howto/python/fibonacci-sequence-python/
# https://es.stackoverflow.com/questions/213161/es-posible-hacer-m%C3%A1s-simple-esta-secuencia-de-fibonacci-en-python-usando-loop
# https://compilar.kryptomsolid.com
