# %%
# area y longitud circulo
import math
rad= float(input("ingrese radio del circulo: "))
area=math.pi*pow(rad,2)
longitud=2*math.pi*rad
print("el area del ciruclo es: ", area)
print("la longitud del circulo es: ", longitud)
# Out:
# ingrese radio del circulo: 50
# el area del ciruclo es:  7853.981633974483
# la longitud del circulo es:  314.1592653589793

# %%
# calcular velocidad
distancia= int(input("ingrese una distancia que desee recorrer: "))
tiempo= int(input("ingrese el timepo: "))
velocidad= distancia/tiempo
print("la velovidad requeria es: ", velocidad)
# Out:
# ingrese una distancia que desee recorrer: 50
# ingrese el timepo: 5
# la velovidad requeria es:  10.0

# %%
# area y perimero del rectangulo
lado1=float(input("ingrese el valor del lado 1: "))
lado2=float(input("ingrese el valor del lado 2: "))
area= lado1*lado2
perimetro= (lado1*2)+(lado2*2)
print("el area es: ", area)
print("el perimeto es: ", perimetro)

# %%
# FUNCION DESARROLLADA POR EL PROGRAMADOR 
# Funcion sin recibir parametros ni retornar valor
# Prototipo
def calcularAreaPerimetro():
  # Desarrollo de la funcion 
  lado1=float(input("ingrese el valor del lado 1: "))
  lado2=float(input("ingrese el valor del lado 2: "))
  area= lado1*lado2
  perimetro= (lado1*2)+(lado2*2)
  print("el area es: ", area)
  print("el perimeto es: ", perimetro)

# Llamado 
calcularAreaPerimetro()
# Out:
# ingrese el valor del lado 1: 5
# ingrese el valor del lado 2: 4
# el area es:  20.0
# el perimeto es:  18.0

# %%
# FUNCION DESARROLLADA POR EL PROGRAMADOR 
# Funcion que recibe parametros ni retornar valor
# Prototipo
def calcularAreaPerimetro(p_Lado1,p_Lado2):
  # Desarrollo de la funcion 
  area= Lado1*ado2
  perimetro= (lado1*2)+(lado2*2)
  print("el area es: ", area)
  print("el perimeto es: ", perimetro)
# Fin de desarrollo de la funcion 

# Llamado 
Lado1=float(input("Ingrese el valor del lado 1: "))
Lado2=float(input("Ingrese el valor del lado 2: "))
calcularAreaPerimetro(Lado1,Lado2)
# Out:
# Ingrese el valor del lado 1: 5
# Ingrese el valor del lado 2: 4
# el area es:  20.0
# el perimeto es:  18.0

# %%
# FUNCION DESARROLLADA POR EL PROGRAMADOR 
# Funcion sin recibir parametros y devolviendo valor
# Prototipo
def calcularArea():
  # Desarrollo de la funcion 
  lado1=float(input("ingrese el valor del lado 1: "))
  lado2=float(input("ingrese el valor del lado 2: "))
  area= lado1*lado2
  return(area)
# Fin de desarrollo de la funcion 

# Llamado 
print("El area es: ",calcularArea())
# Out:
# ingrese el valor del lado 1: 5
# ingrese el valor del lado 2: 4
# El area es:  20.0
