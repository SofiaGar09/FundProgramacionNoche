# %%
class Coche():
# Atributos 
  ruedas = 4
  cilindraje = 1000
  combustible = "Gasolina"
  puertas = 3
# Metodo
  def desplazamiento(self):
      print("El coche se esta desplazando sobre 4 ruedas")

# Programa principal 

# Generar una instancia de la clase
# Instanciar un objeto
# Declarar un objeto 
miVehiculo = Coche()
obj_miCarrito = Coche()
# Acceso al atributo
print("Mi coche tiene ", miVehiculo.ruedas, "ruedas")
print("Mi coche tiene ", miVehiculo.combustible, "de combustible")
print("Mi coche tiene ", miVehiculo.cilindraje, "de cilindraje")
print("Mi coche tiene ", miVehiculo.puertas, "puertas")

# Forma que un objeto solicita que se ejecute un metodo
miVehiculo.desplazamiento()
obj_miCarrito.desplazamiento()
# Out:
# Mi coche tiene  4 ruedas
# Mi coche tiene  Gasolina de combustible
# Mi coche tiene  1000 de cilindraje
# Mi coche tiene  3 puertas
# El coche se esta desplazando sobre 4 ruedas
# El coche se esta desplazando sobre 4 ruedas

# %%
class Coche():
# Atributos 
  ruedas = 4
  def desplazamiento(self):
      print("El coche se esta desplazando sobre 4 ruedas")
class Moto():
  ruedas = 2
  def desplazamiento(self):
      print("El coche se esta desplazando sobre 2 ruedas")
miCarro = Coche()
print("Mi coche tiene ", miCarro.ruedas, "ruedas")
miCarro.desplazamiento()
print("--------Segundo objeto-------")
miMoto = Moto()
print("Mi moto tiene ", miMoto.ruedas, "ruedas")
miMoto.desplazamiento()
# Out:
# Mi coche tiene  4 ruedas
# El coche se esta desplazando sobre 4 ruedas
# --------Segundo objeto-------
# Mi moto tiene  2 ruedas
# El coche se esta desplazando sobre 2 ruedas

# %%
from typing_extensions import Self
# Constructor 
class Cachorro():
  # Metodo Constructor
  def __init__(self, p_color, p_raza):
    self.color = p_color
    self.raza = p_raza

perrito = Cachorro("Marron claro", "Golden Retriver")
obj_perritodeVicky = Cachorro ("Blanco", "Shitzu")
obj_perritodeBryan = Cachorro("Negro", "Sin identificar")

print("Este es un cachorro sin dueño y la raza es  {} y es de color {}".format(perrito.raza, perrito.color))
print("Este es un cachorro de Vicky y la raza es {} y es de color {}".format(obj_perritodeVicky.raza, perrito.color))
print("Este es un cachorro de Bryan y la raza es {} y es de color {}".format(obj_perritodeBryan.raza, perrito.color))
# Out:
# Este es un cachorro sin dueño y la raza es  Golden Retriver y es de color Marron claro
# Este es un cachorro de Vicky y la raza es Shitzu y es de color Marron claro
# Este es un cachorro de Bryan y la raza es Sin identificar y es de color Marron claro

# %%
#Contructor
class Cachorro():
  # Metodo Constructor
  def __init__(self,p_color,p_raza,p_nombre):
    self.color = p_color
    self.raza = p_raza
    self.nombre = p_nombre

# Moduo Principal
p_color = input("Color :")
p_raza = input("Raza :")
p_nombre = input("Nombre :")

perrito = Cachorro(p_color,p_raza,p_nombre)
print("Este es un cachorro sin Dueño y la raza es {} y es de color {} y se llama {}".format(perrito.raza, perrito.color, perrito.nombre))
# Out:
# Color :Gris con Blanco
# Raza :Alaska Malamute
# Nombre :Toby
# Este es un cachorro sin Dueño y la raza es Alaska Malamute y es de color Gris con Blanco y se llama Toby

# %%
class C_Rectangulo:
  def __init__(self,p_ancho,p_alto):
    self.at_ancho = p_ancho
    self.at_alto = p_alto

  def m_area(self):
    area = self.at_alto*self.at_ancho
    return area
  
  def m_perimetro(self):
    perimetro = (self.at_alto*2)+(self.at_ancho*2)
    return perimetro

r1 = C_Rectangulo(4,2)
area = r1.m_area()
perimetro = r1.m_perimetro()
print("El area es: ",area)
print("El perimetro es: ",perimetro)

p_ancho = int(input("Ancho: "))
p_alto = int(input("Alto: "))

obj_rect2=C_Rectangulo(p_ancho,p_alto)

print("El area es: ", +obj_rect2.m_area())
print("El perimetro es: ", +obj_rect2.m_perimetro())
# Out:
# El area es:  8
# El perimetro es:  12
# Ancho: 4
# Alto: 7
# El area es:  28
# El perimetro es:  22
