# %% [markdown]
# Descripcion del Enunciado: Un camion circula por una carretera a 20m/s. En 5s, su velocidad pasa a ser de 25m/s ¿cual ha sido su aceleracion?
# Autor: Sofia Sanchez
# Fecha 2_09_2022
# Version 1.0

# %%
# Declaracion de Variables
var_ent_int_Vi = 0.0
var_ent_int_Tiempo = 0.0
vat_ent_int_Vf = 0.0
var_proSal_int_aceleracion = 0.0 # Variable que Almacena

# %%
# Captura de Datos
var_ent_int_Vi = int(input("Velocidad inicial ;"))
var_ent_int_Tiempo = int(input("Tiempo ;"))
var_ent_int_Vf = int(input("Velocidad final ;"))
# Out:
# Velocidad inicial ;20
# Tiempo ;5
# Velocidad final ;25

# %% [markdown]
# Velocidad inicial: 20
#
# Tiempo: 5
#
# Velocidad final: 25

# %%
# Procesos
var_proSal_int_aceleracion = (var_ent_int_Vf - var_ent_int_Vi)/var_ent_int_Tiempo

# %%
# Salidas
print(var_proSal_int_aceleracion)
# Out:
# 1.0
