# %% [markdown]
# Descripcion del enunciado 2: Construir una funcion que reciba como parametro un entero y retorne sus dos ultimos digitos

# %%
# RECIBIENDO parámetro y  RETORNANADO valor
# Desarrollo de la funcion 
def UltDig2(n):
  UltDig2 = 0
  UltDig2 = n % 100
  return(UltDig2)

# Llamado
n = int(input("Digite numero :"))
print("Sus dos ultimos digitos son :", UltDig2(n))
# Out:
# Digite numero :245
# Sus dos ultimos digitos son : 45

# %%
# SIN RECIBIR parámetro y RETORNANDO valor
def UltDig2():
  # Desarrollo de la funcion
  n = int(input("Digite numero :"))
  UltDig2 = 0
  UltDig2 = n % 100
  return(UltDig2)

  
# Llamado
print("Sus dos ultimos digitos son :", UltDig2())
# Out:
# Digite numero :3567
# Sus dos ultimos digitos son : 67

# %%
# RECIBIENDO parámetro y  NO RETORNANADO valor
def UltDig2(n):
  # Desarrollo de la funcion punto 2-3
  n = int(input("Digite numero :"))
  UltDig2 = 0
  UltDig2 = n % 100
  print("Sus dos ultimos digitos son :", n % 100)

# Llamado
UltDig2(n)
# Out:
# Digite numero :2367
# Sus dos ultimos digitos son : 67

# %%
# SIN RECIBIR parámetro y SIN RETORNAR valor
def UltDig2():
  # Desarrollo de la funcion punto 2-3
  n = int(input("Digite numero :"))
  UltDig2 = 0
  UltDig2 = n % 100
  print("Sus dos ultimos digitos son :", n % 100)

# Llamado
UltDig2()
# Out:
# Digite numero :234
# Sus dos ultimos digitos son : 34
