# %% [markdown]
# Descripcion del enunciado: Construir una funcion que reciba como parametro un entero y retorne 1 si dicho valor es multiplo de 5. Debera retornar 0 si no es asi

# %%
# RECIBIENDO parámetro y  RETORNANADO valor
# Desarrollo de la funcion
def Mult_5(n):
  if n % 5 <= 0:
    return(1)
  else:
    return(0)

#Llamado de la funcion 
n=int(input("Digite numero entero :"))
print("El retorno es : ", Mult_5(n))
# Out:
# Digite numero entero :10
# El retorno es :  1

# %%
# SIN RECIBIR parámetro y RETORNANDO valor
def Mult_5():
  # Desarrollo de la funcion
  n=int(input("Digite numero entero :"))
  if n % 5 <= 0:
    return(1)
  else:
    return(0)

#Llamado de la funcion 
print("El retorno es : ", Mult_5())
# Out:
# Digite numero entero :10
# El retorno es :  1

# %%
# SIN RECIBIR parámetro y  SIN RETORNAR valor
def Mult_5():
  # Desarrollo de la funcion
  n = int(input("Digite numero :"))
  if n % 5 <= 0:
    print ("1")
  else:
    print("0")

#Llamado de la funcion 
Mult_5()
# Out:
# Digite numero :3
# 0

# %%
# RECIBIENDO parámetro y SIN RETORNAR valor
def Mult_5(n):
  if n % 5 <= 0:
    print("1")
  else:
    print("0")

#Llamado de la funcion 
n = int(input("Ingrese numero entero : "))
Mult_5(n)
# Out:
# Ingrese numero entero : 15
# 1
