# %% [markdown]
# **DESCRIPCION DEL ENUNCIADO:** SE DESEA OBTENER LA NOMINA, SEMANAL - SALARIO NETO-DE LOS EMPLEADOS DE UNA EMPRESA CUYA TRABAJOSE PAGA POR HORAS Y De MODO SIGUIENTE: LAS HORAS INFERIORES O IGUALES A 40 HORAS(NORMALES)SE PAGAN A UNA TARIFA QUE SE DEBE INTRODUCIR POR TECLADO ( el valor es por hora) AL IGUAL QUE EL NUMERO DE HORAS Y EL NOMBRE DEL TRABAJADOR. LAS HORAS SUPERIORES A 40 SE PAGARAN COMO EXTRAS A UN PROMEDIO DE 1.8 HORAS NORMALES. LOS INPUESTOS A DEDUCIR AL LOS TRABAJADORES VARIAN EN FUNCION DEL SUELDO MENSUAL:
# -SUELDO>=1.800,00,
# -LAS SIGUENTES 500,000 AL 20 POR 100 EL RESTO,
# -AL 30 POR 100 1

# %%
#declaracion de variables
var_ent_cad_nombreempleado=""
var_ent_if_horas_normales =0.0
var_ent_float_valor_horas_normales =0.0
var_ent_float_horas_extras =0.0 
var_ent_float_valor_horas_extras =0.0
var_ent_float_valor_sueldo_total =0.0
var_ent_float_valor_impuestos_20x100=0.0
var_ent_float_valor_impuestos_30x100=0.0
var_prosal_float_valor_sueldo_con_descuentos = 0.0

# %%
#  captura de datos
var_ent_cad_nombredeempleado = input("nombre empleado : ")
var_ent_if_horas_normales =float(input("horas normales:"))
var_ent_if_horas_extras = float (input('horas extras:')) 
var_ent_if_valor_horas_normales = float(input("valor horas normales:"))
var_ent_if_valor_horas_extras = float(input("valor horas extras :"))
var_ent_if_valor_horas_totales_laboradas = float (input("horas totales laboradas:"))
var_ent_float_valor_impuestos_20x100 = float (input("valor impuestos 20*100:"))
var_ent_float_valor_impuestos_30x100 = float (input("valor impuestos 30*100:"))
var_prosal_float_valor_sueldo_con_descuentos = float (input("valor sueldo con descuentos:"))
# Out:
# nombre empleado : Juan Camilo
# horas normales:40
# horas extras:47
# valor horas normales:1800000
# valor horas extras :360000
# horas totales laboradas:87
# valor impuestos 20*100:100000
# valor impuestos 30*100:3000
# valor sueldo con descuentos:3000000
